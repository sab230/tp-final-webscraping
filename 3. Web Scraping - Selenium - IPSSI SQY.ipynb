# %% [markdown]
# # 3. Web Scraping - Selenium
#
# <img src = 'https://xn--kvin-duranty-beb.fr/wp-content/uploads/2022/10/Web-Scraping-_-IPSSI-PRS-2.png' >
#
#
#
# Dans cet exercice, nous utiliserons la bibliothèque Selenium afin de collecter les données des sites internet suivants :
#
# - Partie 1 : [Doctolib](https://www.doctolib.fr/dentiste/paris)
# Nous continuerons là où Beautifullsoup montrait ses limites en collectant de manière automatisée toutes les pages référencées par Doctolib.
#
#
# - Partie 2 : [Les Echos](https://www.lesechos.fr/)
# Nous collecterons les articles correspondants à la thématique `Intelligence artificielle`.
#
#
#
# # **Partie 1 - [Doctolib](https://www.doctolib.fr/)**
#
#
# <img src='https://upload.wikimedia.org/wikipedia/fr/thumb/7/7f/Logo-doctolib.svg/640px-Logo-doctolib.svg.png'>
#
#
# Les informations que nous souhaitons collecter sont les suivantes :
# - le nom du praticien
# - la profession du praticien
# - l'adresse du praticien
# - la ville du praticien
# - l'image de la fiche Doctolib du praticien
#
#
#
# ## 3.1 Installez la bibliothèque Selenium
# Utilitisez la commande suivante dans votre terminal :  `pip install selenium`

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (4.13.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from selenium) (2022.6.15)
# Requirement already satisfied: attrs>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %% [markdown]
# ## 3.2 Télécharger le webdriver [chrome](https://chromedriver.chromium.org/downloads)
# Placez le ensuite dans le dossier Web-scraping

# %% [markdown]
# ## 3.3 Importer l'objet `webdriver`de la bibliothèque de `selenium`
# Importez également `By` depuis `selenium.webdriver.common.by`

# %%
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium import webdriver
import time

# %%
Keys.ENTER
# Out:
# '\ue007'

# %%
Keys.BACK_SPACE
# Out:
# '\ue003'

# %%
By.CLASS_NAME
# Out:
# 'class name'

# %%
By.ID
# Out:
# 'id'

# %%
By.TAG_NAME
# Out:
# 'tag name'

# %% [markdown]
# ## 3.4 Deffinissez une variable `driver = webdriver.Chrome(DRIVER_PATH)`.
# Où `DRIVER_PATH` est le chemin du web driver téléchargé à la question **3.2** ==> `"./chromedriver"`.

# %%
# Change windows size
options = Options()

# Taille maximale
#options.add_argument("--start-maximized")

# Taille personnalisée
options.add_argument('--window-size=1100,1000')

# Headless
#options.add_argument('--headless')

# Open Chrome
driver = webdriver.Chrome('./data/chromedriver', chrome_options=options)
# Out:
# /var/folders/xg/zbz96gcd1l318nfzl96_m9dm0000gn/T/ipykernel_16534/2364686538.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./data/chromedriver', chrome_options=options)
# /var/folders/xg/zbz96gcd1l318nfzl96_m9dm0000gn/T/ipykernel_16534/2364686538.py:14: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('./data/chromedriver', chrome_options=options)

# %% [markdown]
# ## 3.5 Utilisez la méthode `get(BASE_URL)` de l'objet `driver` puis notez vos observations.
# `BASE_URL`est le lien pointant vers le site de Doctolib `"https://www.doctolib.fr/dentiste/paris"`

# %%
# Access to a website
driver.get('https://www.doctolib.fr')

# %%
# Accept cookies
driver.find_element(By.ID, 'didomi-notice-agree-button').click()

# %%
# Search for a doctor (Generalist)
driver.find_element(By.ID, ':r0:').send_keys('Médecin généraliste')

#driver.find_element(By.CLASS_NAME,'searchbar-input searchbar-place-input'.replace(' ', '.')).send_keys('Lyon')
driver.get('https://www.doctolib.fr/medecin-generaliste/lyon')

# Click on the first suggestion
driver.find_element(By.CLASS_NAME, 'Tappable-inactive dl-button-primary searchbar-submit-button dl-button dl-button-size-medium'.replace(' ', '.')).click()

# %% [markdown]
# ## 3.6 Affichez l'adresse url courante ainsi que le titre de la page.

# %%
# Get current URL
driver.current_url
# Out:
# 'https://www.doctolib.fr/medecin-generaliste/garges-les-gonesse'

# %% [markdown]
# ## 3.7 Récupérez dans une variable `selection` la liste des praticients présents sur la page.
# Utilisez la méthéode `find_elements`, cette méthode prend deux arguments `By.CLASS_NAME` ainsi que le nom de la class recherchée sur la page.

# %%
selection = driver.find_elements(By.TAG_NAME, 'article')
selection
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4550")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4551")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_1246")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_1247")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4552")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4553")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4554")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4555")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4556")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4557")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4558")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4559")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4560")>,
#  <selenium.webdriver.remote.webelement.WebElement (session
#  'Dr Aicha Taibi\nMédecin généraliste\n2 Rue Edith Piaf\n95140 Garges-lès-Gonesse\nConventionné secteur 2 avec OPTAM\nPRENDRE RENDEZ-VOUS',
#  'Dr Aicha Taibi\nMédecin généraliste\n2 Rue Edith Piaf\n95140 Garges-lès-Gonesse\nConventionné secteur 2 avec OPTAM\nPRENDRE RENDEZ-VOUS',
#  'Dr Addil Mushtaq\nMédecin généraliste\n3 Rue Alfred Sisley\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Addil Mushtaq\nMédecin généraliste\n3 Rue Alfred Sisley\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Haim DERHY\nMédecin généraliste\n7 Avenue Frédéric Joliot-Curie\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Haim DERHY\nMédecin généraliste\n7 Avenue Frédéric Joliot-Curie\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Simon ARMENIER\nMédecin généraliste\n4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Simon ARMENIER\nMédecin généraliste\n4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Abdoul Ahad Diop\nMédecin généraliste\n14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse\nPRENDRE RENDEZ-VOUS',
#  'Dr Abdoul Ahad Diop\nMédecin généraliste\n14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse\nPRENDRE RENDEZ-VOUS',
#  'Mme Camila Rasneur\nAdjointe médecin\n14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse\nPRENDRE RENDEZ-VOUS',
#  'Mme Camila Rasneur\nAdjointe médecin\n14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse\nPRENDRE RENDEZ-VOUS',
#  'Florie Fournioux\nMédecin généraliste\n4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Florie Fournioux\nMédecin généraliste\n4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Akil Asghar Ali\nMédecin généraliste\n9 Avenue de la Commune de Paris\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Akil Asghar Ali\nMédecin généraliste\n9 Avenue de la Commune de Paris\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Radia OUMERACI\nMédecin généraliste\n4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Radia OUMERACI\nMédecin généraliste\n4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Samir SABER\n1,4 km\nMédecin généraliste\n12 Rue Vincent Van Gogh\n95200 Sarcelles\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Samir SABER\n1,4 km\nMédecin généraliste\n12 Rue Vincent Van Gogh\n95200 Sarcelles\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Kadder ZERROUK\n1,4 km\nMédecin généraliste\n12 Rue Vincent Van Gogh\n95200 Sarcelles\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Kadder ZERROUK\n1,4 km\nMédecin généraliste\n12 Rue Vincent Van Gogh\n95200 Sarcelles\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Antonio SANCHEZ\n1,8 km\nMédecin généraliste\n2 Rue des Peupliers\n93240 Stains\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS',
#  'Dr Antonio SANCHEZ\n1,8 km\nMédecin généraliste\n2 Rue des Peupliers\n93240 Stains\nConventionné secteur 1\nPRENDRE RENDEZ-VOUS']

# %% [markdown]
# ## 3.8 Affichez les information du premier élément de `selection` via son instance `text`.

# %%
[doctor.find_elements(By.CLASS_NAME, 'flex.flex-wrap.gap-x-4')[0].text for doctor in selection]
# Out:
# ['Rue Edith Piaf\n95140 Garges-lès-Gonesse',
#  'Rue Edith Piaf\n95140 Garges-lès-Gonesse',
#  '17 Rue Victor Hugo\n95140 Garges-lès-Gonesse',
#  '17 Rue Victor Hugo\n95140 Garges-lès-Gonesse',
#  '8 Rue Gisèle Halimi\n95140 Garges-lès-Gonesse',
#  '8 Rue Gisèle Halimi\n95140 Garges-lès-Gonesse',
#  '18 Rue Auguste Renoir\n95140 Garges-lès-Gonesse',
#  '18 Rue Auguste Renoir\n95140 Garges-lès-Gonesse',
#  '3 Rue Alfred Sisley\n95140 Garges-lès-Gonesse',
#  '3 Rue Alfred Sisley\n95140 Garges-lès-Gonesse',
#  '3 Rue Alfred Sisley\n95140 Garges-lès-Gonesse',
#  '3 Rue Alfred Sisley\n95140 Garges-lès-Gonesse',
#  '14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse',
#  '14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse',
#  '6 Rue Gisèle Halimi\n95140 Garges-lès-Gonesse',
#  '6 Rue Gisèle Halimi\n95140 Garges-lès-Gonesse',
#  '2 Rue Edith Piaf\n95140 Garges-lès-Gonesse',
#  '2 Rue Edith Piaf\n95140 Garges-lès-Gonesse',
#  '3 Rue Alfred Sisley\n95140 Garges-lès-Gonesse',
#  '3 Rue Alfred Sisley\n95140 Garges-lès-Gonesse',
#  '7 Avenue Frédéric Joliot-Curie\n95140 Garges-lès-Gonesse',
#  '7 Avenue Frédéric Joliot-Curie\n95140 Garges-lès-Gonesse',
#  '4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse',
#  '4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse',
#  '14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse',
#  '14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse',
#  '14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse',
#  '14 Rue Philibert Delorme\n95140 Garges-lès-Gonesse',
#  '4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse',
#  '4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse',
#  '9 Avenue de la Commune de Paris\n95140 Garges-lès-Gonesse',
#  '9 Avenue de la Commune de Paris\n95140 Garges-lès-Gonesse',
#  '4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse',
#  '4 Rue Jean-François Chalgrin\n95140 Garges-lès-Gonesse',
#  '12 Rue Vincent Van Gogh\n95200 Sarcelles',
#  '12 Rue Vincent Van Gogh\n95200 Sarcelles',
#  '12 Rue Vincent Van Gogh\n95200 Sarcelles',
#  '12 Rue Vincent Van Gogh\n95200 Sarcelles',
#  '2 Rue des Peupliers\n93240 Stains',
#  '2 Rue des Peupliers\n93240 Stains']

# %% [markdown]
# ## 3.9 Recherchez à nouveau à l'aide de la méthode `find_element` la photo du premier praticien figurant dans la liste ``selection``.

# %% [markdown]
# ## 3.10 Récupérez à présent le lien de cette image en utilisant la méthode `get_attribute`.

# %% [markdown]
# ## 3.11 Créez une fonction `collect_data` qui renvoie un fichier `json` contenant les informations de tous les praticiens ainsi que leurs photos de profil.

# %% [markdown]
# ## 3.9 Automatisez la collecte sur les pages 5 premières pages de résultats.

# %%
driver = webdriver.Chrome('./chromedriver')

driver.get('https://www.doctolib.fr/medecin-generaliste/lyon')
# Out:
# /var/folders/xg/zbz96gcd1l318nfzl96_m9dm0000gn/T/ipykernel_48747/2979822773.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')

# %%
selection = driver.find_elements(By.CLASS_NAME, 'dl-card dl-card-bg-white dl-card-variant-default dl-card-border dl-padding-0 dl-p-doctor-result-card'.replace(' ', '.'))
len(selection)
# Out:
# 20

# %%
selection[-1]
# Out:
# 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/drzuhcckehftwm90xgfz'

# %%
str(0+1)
# Out:
# '1'

# %%
presentation = driver.find_elements(By.CLASS_NAME, 'dl-search-result')

# %%
presentation[0].text.split('\n')
# Out:
# ['Dr Cao Thang PHAM',
#  'Médecin généraliste',
#  'Consultation vidéo disponible',
#  'En savoir plus',
#  '87 Avenue Paul Santy',
#  '69008 Lyon',
#  'Conventionné secteur 1',
#  'PRENDRE RENDEZ-VOUS']

# %%
presentation[0].find_element(By.TAG_NAME, 'h3')

# %%
driver.find_elements(By.CLASS_NAME, 'dl-search-result-presentation')[0].find_element(By.CLASS_NAME, 'dl-link').text
# Out:
# ''

# %%
# Headless 
from selenium.webdriver.chrome.options import Options

options = Options()
#options.add_argument('--headless')

driver = webdriver.Chrome('./chromedriver', options=options)

driver.get('https://www.doctolib.fr/medecin-generaliste/lyon')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       4 options = Options()
#       5 #options.add_argument('--headless')
# ----> 7 driver = webdriver.Chrome('./chromedriver', options=options)
#       9 driver.get('https://www.doctolib.fr/medecin-generaliste/lyon')
#
# NameError: name 'webdriver' is not defined

# %%
driver.find_element(By.TAG_NAME, 'article')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2da432c2177282cdf251230dc3594af0", element="2F545052C36797E2E40FFDE319536664_element_4550")>

# %%
# Headless 
from selenium.webdriver.chrome.options import Options


def collect_data_from_doctolib(url='https://www.doctolib.fr/medecin-generaliste/lyon', n=1):
    options = Options()
    #options.add_argument('--headless')

    driver = webdriver.Chrome('./chromedriver', options=options)
    driver.get(url)
    driver.find_element(By.ID, 'didomi-notice-agree-button').click()

    data = {}

    for i in range(n):
        driver.get(url+f'?page={str(i+1)}')
        time.sleep(3)

        try:
            selection = driver.find_elements(By.CLASS_NAME, 'dl-search-result-presentation')
        except:
            try:
                selection = driver.find_elements(By.TAG_NAME, 'article')
            except:
                selection = driver.find_elements(By.CLASS_NAME, 'dl-card dl-card-bg-white dl-card-variant-default dl-card-border dl-padding-0 dl-p-doctor-result-card'.replace(' ', '.'))

        for doctor in selection:

            infos = doctor.text.split('\n')
            if len(infos)>2:
                id = doctor.get_attribute('id').split('-')[-1]

                data[id] = {
                    'Name' : infos[0],
                    'Address' : infos[1],
                    'image' : doctor.find_element(By.TAG_NAME, 'img').get_attribute('src')
                }
        print('Collecting page : ', i+1)
    return data

# %%
collect_data_from_doctolib()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 collect_data_from_doctolib()
#
# Cell In[2], line 9, in collect_data_from_doctolib(url, n)
#       6 options = Options()
#       7 #options.add_argument('--headless')
# ----> 9 driver = webdriver.Chrome('./chromedriver', options=options)
#      10 driver.get(url)
#      11 driver.find_element(By.ID, 'didomi-notice-agree-button').click()
#
# NameError: name 'webdriver' is not defined

# %%
# Headless 
from selenium.webdriver.chrome.options import Options

def data_collect_doctolib(url='https://www.doctolib.fr/medecin-generaliste/lyon'):
    options = Options()
    #options.add_argument('--headless')

    driver = webdriver.Chrome('./data/chromedriver', options=options)

    data = {}

    for i in range(6):
        driver.get(url +f'?page={str(i+1)}')
        time.sleep(2)
        selection = driver.find_elements(By.CLASS_NAME, 'dl-search-result')
        print(len(selection))

        for doctor in selection:
            print(doctor.text)
            indos = doctor.text.split('\n')
            id = doctor.get_attribute('id').split('-')[-1]

            data[id] = {
                'Name' : indos[0],
                'Address' : indos[1],
                'image' : doctor.find_element(By.TAG_NAME, 'img').get_attribute('src')
            }
        print('Collecting page : ', i+1)
    
    return data

# %%
data_collect_doctolib()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data_collect_doctolib()
#
# Cell In[25], line 8, in data_collect_doctolib(url)
#       5 options = Options()
#       6 #options.add_argument('--headless')
# ----> 8 driver = webdriver.Chrome('./data/chromedriver', options=options)
#      10 data = {}
#      12 for i in range(6):
#
# NameError: name 'webdriver' is not defined

# %% [markdown]
# # **Partie 2 - Collectes automatisée | [Les Echos](https://www.lesechos.fr/)**
#
#
#
# <br>
#
# <br>
#
#
# <img src = 'https://upload.wikimedia.org/wikipedia/fr/thumb/b/bb/Les_echos_%28logo%29.svg/1200px-Les_echos_%28logo%29.svg.png'>
#
# <br><br>
#
# Les informations que nous souhaitons collecter sont les suivantes :
#
# - l’auteur,
# - la date de publication,
# - le titre,
# - le contenu de la page,

# %%
from selenium.webdriver.chrome.options import Options

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome('./chromedriver')

driver.get('https://www.journaldugeek.com/')
driver.find_element(By.CLASS_NAME, 'flex.gap-4.sm:gap-8.my-4.group').click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\sabrina\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\common\driver_finder.py:38, in DriverFinder.get_path(service, options)
#      37 try:
# ---> 38     path = SeleniumManager().driver_location(options) if path is None else path
#      39 except Exception as err:
#
# File c:\Users\sabrina\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\common\selenium_manager.py:84, in SeleniumManager.driver_location(self, options)
#      77 """Determines the path of the correct driver.
#      78
#      79 :Args:
#      80  - browser: which browser to get the driver path for.
#      81 :Returns: The driver path to use
#      82 """
# ---> 84 browser = options.capabilities["browserName"]
#      86 args = [str(self.get_binary()), "--browser", browser]
#
# AttributeError: 'str' object has no attribute 'capabilities'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 4
#       1 from selenium import webdriver
#       2 from selenium.webdriver.common.by import By
# ----> 4 driver = webdriver.Chrome('./chromedriver')
#       6 driver.get('https://www.journaldugeek.com/')
#       7 driver.find_element(By.CLASS_NAME, 'flex.gap-4.sm:gap-8.my-4.group').click()
#
# File c:\Users\sabrina\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File c:\Users\sabrina\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\chromium\webdriver.py:49, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      37 """Creates a new WebDriver instance of the ChromiumDriver. Starts the
#      38 service and then creates new WebDriver instance of ChromiumDriver.
#      39
#    (...)
#      45  - keep_alive - Whether to configure ChromiumRemoteConnection to use HTTP keep-alive.
#      46 """
#      47 self.service = service
# ---> 49 self.service.path = DriverFinder.get_path(self.service, options)
#      50 self.service.start()
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#
# File c:\Users\sabrina\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\common\driver_finder.py:40, in DriverFinder.get_path(service, options)
#      38     path = SeleniumManager().driver_location(options) if path is None else path
#      39 except Exception as err:
# ---> 40     msg = f"Unable to obtain driver for {options.capabilities['browserName']} using Selenium Manager."
#      41     raise NoSuchDriverException(msg) from err
#      43 if path is None or not Path(path).is_file():
#
# AttributeError: 'str' object has no attribute 'capabilities'

# %%
options = Options()
options.add_argument("--headless")

driver = webdriver.Chrome('./data/chromedriver', chrome_options=options)


driver.get('https://www.lesechos.fr/recherche?q=IA')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 4
#       1 options = Options()
#       2 options.add_argument("--headless")
# ----> 4 driver = webdriver.Chrome('./data/chromedriver', chrome_options=options)
#       7 driver.get('https://www.lesechos.fr/recherche?q=IA')
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'chrome_options'

# %%
from bs4 import BeautifulSoup
options = Options()
options.add_argument("--headless")

driver = webdriver.Chrome('./chromedriver', chrome_options=options)


driver.get('https://www.lesechos.fr/recherche?q=IA')
time.sleep(1)
#driver.find_elements(By.ID, 'didomi-notice-agree-button')[0].click()
driver.find_elements(By.TAG_NAME, 'article')[1].click()

time.sleep(1)
soup = BeautifulSoup(driver.page_source.split('Par ')[1], 'html.parser')
print(soup.find('a').text)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 5
#       2 options = Options()
#       3 options.add_argument("--headless")
# ----> 5 driver = webdriver.Chrome('./chromedriver', chrome_options=options)
#       8 driver.get('https://www.lesechos.fr/recherche?q=IA')
#       9 time.sleep(1)
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'chrome_options'

# %%
driver.page_source
# Out:
# '<html lang="fr" data-rh="lang"><head><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.old.min.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script async="" src="https://snap.licdn.com/li.lms- ...

# %% [markdown]
# ---
# # **Partie 3 : Programation Orientée Objet et Gestion d'une base de données**
#
#
#
# ### **1. Définition d'une Classe**
# **Definition**
#
# La programmation orientée objet (POO) est un paradigme de programmation qui repose sur le concept d'objets. Dans ce paradigme, le code est organisé autour d'entités appelées "objets", qui représentent des instances concrètes ou abstraites de concepts du monde réel. Chaque objet peut avoir des propriétés (appelées attributs) et des comportements (appelés méthodes).
#
# Voici quelques concepts clés de la programmation orientée objet :
#
# - **Objets** : Les objets sont des instances spécifiques d'une classe, qui est un modèle ou un plan pour créer des objets. Par exemple, si une classe est définie pour représenter des voitures, un objet spécifique pourrait être une voiture particulière.
#
# - **Classes** : Les classes sont des structures qui définissent la manière dont les objets sont créés. Elles définissent les attributs (caractéristiques) et les méthodes (comportements) que les objets de la classe auront. Une classe est une sorte de modèle à partir duquel des objets peuvent être créés.
#
# - **Encapsulation** : L'encapsulation est le principe de regrouper les données (attributs) et les méthodes qui les manipulent au sein d'une même entité, c'est-à-dire une classe. Cela permet de cacher les détails d'implémentation et d'isoler le fonctionnement interne de l'objet.
#
# - **Héritage** : L'héritage est un mécanisme qui permet à une classe d'hériter des propriétés et des méthodes d'une autre classe. Cela favorise la réutilisation du code et la création de hiérarchies de classes.
#
# - **Polymorphisme** : Le polymorphisme permet à un même nom de méthode d'avoir des comportements différents en fonction du contexte. Il existe deux types de polymorphisme : le polymorphisme statique (surcharge) et le polymorphisme dynamique (redéfinition).
#
# - **Abstraction** : L'abstraction consiste à simplifier un concept complexe en modélisant uniquement les aspects pertinents tout en masquant les détails complexes.
#
#       # Déclaration d'une classe, paramètre 1 et 2 seront
#
#       class NomDeLaClasse:
#         # Définition des attributs au moment de l'instanciation
#         def __init__(self, parametre1, parametre2):
#           self.parametre1 = parametre1
#           self.parametre2 = parametre2
#
#         def __repr__(self):
#           return "Exemple de retour"
#
#         # Définition d'une méthode
#         def nom_de_la_methode(self, p1, p2):
#           self.value = p1 * p2 # Création d'un nouvel attribut
#
#       # Instance de classe
#       objet = NomDeLaClasse('parametre1', 'parametre2')
#
#       # Héritage :
#       class ClasseFille(NomDeLaClasseMère):
#         def __init__(self, parametre1, parametre2, parametre3):
#           NomDeLaClasseMère.__init__(self, parametre1, parametre2)
#           self.parametre3 = parametre3
#
#         # Méthode utilisable uniquement dans la classe :
#         def __methode_encapsulee(self):
#           print("Test")
#
#
# - __init__: permet de définir les attributs nécessaires à l'objet lors de son instanciation.
# - __repr__: permet de définir le type d'objet retourné par défaut.
# - __str__ : permet de définir ce qui est affiché par défaut lorsque l'on print un objet.
# - __add__ : permet de définir ce ci se produit lorsque l'on additionne des objets entre eux.

# %%
# Définir une classe

class Voiture:
    def __init__(self, brand:str, model:str, color:str, km:int=10):
        self.brand = brand
        self.model = model
        self.color = color
        self.km = km

    def travel(self, position:str, destination:str, distance:int) -> str:
        """ 
        Permet de se déplacer d'un point A à un point B

        Parameters
        ----------
        position : str
            Position actuelle de la voiture
        destination : str

        distance : int
            Distance à parcourir

        Returns
        -------
        str
            Position actuelle de la voiture
        """
        self.destination = destination
        self.position = position

        self.km += distance

        return f'Position actuelle {self.position}'

    def show_data(self, *args):
        for arg in args:
            print(arg)

    def show_multiple_data(self, **kwargs):
        print(kwargs)

# %%
# Instancier un objet
voiture = Voiture('Peugeot', 306, 'rouge', 10)

voiture.show_multiple_data(name='Kevin', age=25, job='Data Scientist')
# Out:
# {'name': 'Kevin', 'age': 25, 'job': 'Data Scientist'}

# %%
list_data = ['Kevin', 25, 'Data Scientist']

# %%
voiture.show_data(*list_data)
# Out:
# Kevin
# 25
# Data Scientist

# %%
type(voiture.model)
# Out:
# int

# %%
[1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
voiture.travel

# %%
# Héritage
class VoitureElectrique(Voiture):
    def __init__(self, brand:str, model:str, color:str, km:int=10, battery:int=100):
        super().__init__(brand, model, color, km)
        self.battery = battery

    def travel(self, position:str, destination:str, distance:int) -> str:
        """ 
        Permet de se déplacer d'un point A à un point B

        Parameters
        ----------
        position : str
            Position actuelle de la voiture
        destination : str

        distance : int
            Distance à parcourir

        Returns
        -------
        str
            Position actuelle de la voiture
        """
        self.destination = destination
        self.position = position

        self.km += distance
        self.battery -= distance

        return f'Position actuelle {self.position}'

# %% [markdown]
# ### **2. Gestion d'une base de données avec la bibliothèque [SQLalchemy](https://docs.sqlalchemy.org/en/14/)**
#
# <img src='https://miro.medium.com/v2/resize:fit:1400/0*msfsws06ImMSJYop.jpg'>
#
# SQLAlchemy est une bibliothèque Python très populaire qui facilite l'interaction avec des bases de données relationnelles en utilisant un langage Python. Elle fournit un ensemble d'outils puissants pour travailler avec des bases de données SQL tout en offrant une abstraction flexible qui permet de travailler avec différents types de bases de données.
#
# Voici quelques caractéristiques clés de SQLAlchemy :
#
# **ORM (Object-Relational Mapping)** : SQLAlchemy propose un ORM qui permet de représenter des tables de base de données sous forme d'objets Python. Ces objets peuvent être manipulés comme n'importe quel autre objet Python, offrant ainsi une abstraction plus élevée des opérations sur la base de données.
#
# **Prise en Charge de Diverses Bases de Données** : SQLAlchemy prend en charge plusieurs types de bases de données, y compris MySQL, PostgreSQL, SQLite, Oracle, et d'autres.
#
# **Flexibilité** : Vous pouvez utiliser SQLAlchemy de manière transparente avec un ORM complet, un langage SQL pur, ou une combinaison des deux, en fonction des besoins de votre application.
#
# **Communauté Active** : SQLAlchemy est largement utilisé dans la communauté Python et dispose d'une documentation complète et d'une base d'utilisateurs active.
#
# ---
#
#
# 1. Installation de la bibliothèque : `pip install SQLAlchemy`
#
# 2. Installez [SQLite Viewer](https://marketplace.visualstudio.com/items?itemName=qwtel.sqlite-viewer) pour visualiser votre base données.
#
# <img src='https://qwtel.gallerycdn.vsassets.io/extensions/qwtel/sqlite-viewer/0.3.13/1691231169503/Microsoft.VisualStudio.Services.Icons.Default'>

# %%
import sqlalchemy as db

# %%
db.__version__
# Out:
# '1.4.40'

# %%
# Gestion d'une base de données
import sqlalchemy as db

class DataBase():
    def __init__(self, name_database='journaldugeek'):
        self.name = name_database
        self.url = f"sqlite:///{name_database}.db"
        self.engine = db.create_engine(self.url)
        self.connection = self.engine.connect()
        self.metadata = db.MetaData()
        self.table = self.engine.table_names()


    def create_table(self, name_table, **kwargs):
        colums = [db.Column(k, v, primary_key = True) if 'id_' in k else db.Column(k, v) for k,v in kwargs.items()]
        db.Table(name_table, self.metadata, *colums)
        self.metadata.create_all(self.engine)
        print(f"Table : '{name_table}' are created succesfully")

    def read_table(self, name_table, return_keys=False):
        table = db.Table(name_table, self.metadata, autoload=True, autoload_with=self.engine)
        if return_keys:table.columns.keys()
        else : return table


    def add_row(self, name_table, **kwarrgs):
        name_table = self.read_table(name_table)

        stmt = (
            db.insert(name_table).
            values(kwarrgs)
        )
        self.connection.execute(stmt)
        print(f'Row id added')

    def select_table(self, name_table):
        name_table = self.read_table(name_table)
        stm = db.select([name_table])
        return self.connection.execute(stm).fetchall()

# %%
# Création d'une base de données
database = DataBase('journaldugeek')
# Out:
# C:\Users\sabrina\AppData\Local\Temp\ipykernel_12836\1506822421.py:11: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   self.table = self.engine.table_names()

# %%
# Création d'un Tableau1
database.create_table('articles', titre=db.String, link=db.String, theme=db.String, image=db.String, author=db.String)
# Out:
# Table : 'articles' are created succesfully

# %%
# Création d'un Tableau2
database.create_table('Tableau2', id_shop=db.Integer, id_colonne1=db.String, colonne2=db.Integer)
# Out:
# Table : 'Tableau2' are created succesfully

# %%
# Visualiser les tables
database = DataBase('data')
database.table
# Out:
# C:\Users\sabrina\AppData\Local\Temp\ipykernel_12836\4235633602.py:11: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   self.table = self.engine.table_names()
# ['Tableau1', 'Tableau2']

# %%
# Ajouter une ligne à la base de données
database.add_row('Tableau2', id_shop=3086, id_colonne1='Iphone')
# Out:
# Row id added

# %%
# Ajouter plusieurs lignes à la base de données
for i in range(10):
    database.add_row('Tableau2',id_shop=i, id_colonne1='Iphone'*(i+1), colonne2=99*i)

database.select_table('Tableau2')
# Out:
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# [(3086, 'Iphone', None),
#  (0, 'Iphone', 0),
#  (1, 'IphoneIphone', 99),
#  (2, 'IphoneIphoneIphone', 198),
#  (3, 'IphoneIphoneIphoneIphone', 297),
#  (4, 'IphoneIphoneIphoneIphoneIphone', 396),
#  (5, 'IphoneIphoneIphoneIphoneIphoneIphone', 495),
#  (6, 'IphoneIphoneIphoneIphoneIphoneIphoneIphone', 594),
#  (7, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 693),
#  (8, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 792),
#  (9, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 891)]

# %%
# Afficher le Tableau1
import pandas as pd
pd.DataFrame(database.select_table('Tableau2'))
# Out:
#     id_shop                                        id_colonne1  colonne2
# 0      3086                                             Iphone       NaN
# 1         0                                             Iphone       0.0
# 2         1                                       IphoneIphone      99.0
# 3         2                                 IphoneIphoneIphone     198.0
# 4         3                           IphoneIphoneIphoneIphone     297.0
# 5         4                     IphoneIphoneIphoneIphoneIphone     396.0
# 6         5               IphoneIphoneIphoneIphoneIphoneIphone     495.0
# 7         6         IphoneIphoneIphoneIphoneIphoneIphoneIphone     594.0
# 8         7   IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone     693.0
# 9         8  IphoneIphoneIphoneIphoneIphoneIphoneIphoneIpho...     792.0
# 10        9  IphoneIphoneIphoneIphoneIphoneIphoneIphoneIpho...     891.0

# %% [markdown]
# # Exercice Collecte d’articles sur le site [Cdiscount](https://www.cdiscount.com/)
#
# <img src='https://marketplace.cdiscount.com/wp-content/uploads/2020/06/french-days-cdiscount.jpg'>
#
# Dans cet exercice nous allons collecter les informations des articles présents sur le site Cdiscount.
# Parmis une liste de produit, collectez dans une base de données les informations suivantes :
# - le nom de l’article,
# - le lien de l’image,
# - le lien de l’article
# - le prix de l’article
# - la note de l’article
#
# Nous créerons un script qui automatisera la collecte des données en prenant en compte les exceptions et qui retournera un fichier csv contenant l'ensemble de nos données. Voici la liste des produits à collecter (choisir un article) :
# - Iphone 13
# - Samsung Galaxy S21
# - Xiaomi Redmi Note 10
#
# 1. Créez une fonction `collecte_Cdiscount` qui prends en entrée une chaine de caractère (produit à collecter) et qui retourne un fichier csv contenant les produits scrappé avec la bibliothèque Selenium.
# 2. Placez cette fonction dans un fichier `functions.py`.
# 3. Créez une page dans votre application streamlit qui demande à l'utilisateur de saisir le nom d'un produit à collecter puis fait appel à la fonction `collecte_Cdiscount` pour collecter ces produits. La collecte ne doit pas ouvrir de navigateur.
# 4. Ajoutez les données dans une base de données MySQL ou SQL Lite.

# %%
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium import webdriver
import time

def data_collect_products_from_cdiscount(product="Iphon 13", np_page=2):
    driver = webdriver.Chrome('./data/chromedriver')

    # Création/connexion à la base de données
    database = DataBase('data/data_cdiscount')

    driver.get('https://www.cdiscount.com/')
    time.sleep(2)

    # Accept cookies
    driver.find_element(By.ID, "footer_tc_privacy_button_2").click()

    # Search for a product
    driver.find_element(By.ID, 'search').send_keys(product + Keys.ENTER)

    # Create a table
    try:
        database.create_table(product, 
                          id_product=db.String, 
                          name=db.String, 
                          star=db.String, 
                          image=db.String, 
                          price=db.String)
    except:pass

    data = {}

    for n in range(np_page):
        time.sleep(2)
        
        template_products = driver.find_element(By.ID, 'lpBloc')
        list_article = template_products.find_elements(By.TAG_NAME, 'li')
        
        for article in list_article:
            if article.get_attribute('data-sku'):
                id = article.get_attribute('data-sku')

                try:name = article.find_element(By.TAG_NAME, 'a').text
                except:name = None

                try:star = article.find_element(By.CLASS_NAME, 'u-visually-hidden').text
                except:star = None

                try:image = article.find_element(By.TAG_NAME, 'img').get_attribute('src')
                except:image = None

                try:price = article.find_element(By.CLASS_NAME, 'lpSavings').text
                except:price = None

                data[id] = {
                    'name' : name,
                    'star' : star,
                    'image' : image,
                    'price' : price
                }
                try:
                    database.add_row(product, 
                                 id_product=id, 
                                 name=name, 
                                 star=star, 
                                 image=image, 
                                 price=price)
                except:pass


        # Change page
        try:driver.find_element(By.CLASS_NAME, 'jsNxtPage'.replace(' ', '.')).click()
        except:
            try:driver.find_element(By.CLASS_NAME, 'jsNxtPage'.replace(' ', '.')).click()
            except:pass

    driver.quit()
    return data

# %%
data = data_collect_products_from_cdiscount(product="Iphon 13", np_page=2)
# Out:
# /var/folders/xg/zbz96gcd1l318nfzl96_m9dm0000gn/T/ipykernel_16814/3347568301.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./data/chromedriver')
# /var/folders/xg/zbz96gcd1l318nfzl96_m9dm0000gn/T/ipykernel_16814/4235633602.py:11: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   self.table = self.engine.table_names()
# Table : 'Iphon 13' are created succesfully

# %%
data
# Out:
# {'APP0194252707289': {'name': 'iPhone 13 128Go Midnight',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/2/8/9/1/300x300/app0194252707289/rw/iphone-13-128go-midnight.jpg',
#   'price': '909,00€\nPrix de comparaison\n699€00'},
#  'APP0194252708361': {'name': 'iPhone 13 128Go Blue',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/3/6/1/1/300x300/app0194252708361/rw/iphone-13-128go-blue.jpg',
#   'price': '909,00€\nPrix de comparaison\n699€00'},
#  'APP0194252707821': {'name': 'iPhone 13 128Go Pink',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/8/2/1/1/300x300/app0194252707821/rw/iphone-13-128go-pink.jpg',
#   'price': '909,00€\nPrix de comparaison\n699€00'},
#  'IP13128GREEN': {'name': 'iPhone 13 128Go Vert',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/e/n/1/300x300/ip13128green/rw/iphone-13-128go-vert.jpg',
#   'price': '909,00€\nPrix de comparaison\n699€00'},
#  'IPHONE13512ROUGE': {'name': 'APPLE iPhone 13 512Go (PRODUCT) RED',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/u/g/e/1/300x300/iphone13512rouge/rw/apple-iphone-13-512go-product-red.jpg',
#   'price': '1259,00€\nPrix de comparaison\n1079€00'},
#  'IPHONE13512ROSE': {'name': 'APPLE iPhone 13 512Go Pink',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/o/s/e/1/300x300/iphone13512rose/rw/apple-iphone-13-512go-pink.jpg',
#   'price': '1259,00€\nPrix de comparaison\n1079€00'},
#  'APP0194252709177': {'name': 'iPhone 13 256Go Pink',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/1/7/7/1/300x300/app0194252709177/rw/iphone-13-256go-pink.jpg',
#   'price': '1029,00€\nPrix de comparaison\n829€00'},
#  'IP13256GREEN': {'name': 'iPhone 13 256Go Vert',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/e/n/1/300x300/ip13256green/rw/iphone-13-256go-vert.jpg',
#   'price': '1029,00€\nPrix de comparaison\n829€00'},
#  'APP0194252708095': {'name': 'iPhone 13 128Go Red',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/0/9/5/1/300x300/app0194252708095/rw/iphone-13-128go-red.jpg',
#   'price': '909,00€\nPrix de comparaison\n699€00'},
#  'IP13512GREEN': {'name': 'iPhone 13 512Go Vert',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/e/n/1/300x300/ip13512green/rw/iphone-13-512go-vert.jpg',
#   'price': '1259,00€\nPrix de comparaison\n1079€00'},
#  'RCDAPP0032098EXE': {'name': 'APPLE iPhone 13 128 Go Midnight (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0032098exe/rw/apple-iphone-13-128-go-midnight-2021-reconditi.jpg',
#   'price': '499€00'},
#  'RCDAPP0034630EXE': {'name': 'APPLE iPhone 13 128 Go Pink (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0034630exe/rw/apple-iphone-13-128-go-pink-2021-reconditionne.jpg',
#   'price': '497€69'},
#  'RCDAPP0033364EXE': {'name': 'APPLE iPhone 13 128 Go Starlight (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0033364exe/rw/apple-iphone-13-128-go-starlight-2021-recondit.jpg',
#   'price': '499€99'},
#  'RCDAPP0036170EXE': {'name': 'APPLE iPhone 13 128 Go Bleu (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0036170exe/rw/apple-iphone-13-128-go-bleu-2021-reconditionne.jpg',
#   'price': '499€99'},
#  'RCDAPP0029011EXE': {'name': 'APPLE iPhone 13 128 Go Vert - Reconditionné - Excellent état',
#   'star': 'Score global : 4 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0029011exe/rw/apple-iphone-13-128-go-vert-reconditionne-exce.jpg',
#   'price': '494€94'},
#  'RCDAPP0003062EXE': {'name': 'APPLE iPhone 13 mini 128 Go Pink (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0003062exe/rw/apple-iphone-13-mini-128-go-pink-2021-recondit.jpg',
#   'price': '465€00'},
#  'RCDAPP0035906EXE': {'name': 'APPLE iPhone 13 128 Go Rouge (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0035906exe/rw/apple-iphone-13-128-go-rouge-2021-reconditionn.jpg',
#   'price': '495€99'},
#  'RCDAPP0039989EXE': {'name': 'APPLE iPhone 13 256 Go Pink (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0039989exe/rw/apple-iphone-13-256-go-pink-2021-reconditionne.jpg',
#   'price': '558€94'},
#  'RCDAPP0002790EXE': {'name': 'APPLE iPhone 13 mini 128 Go Starlight (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0002790exe/rw/apple-iphone-13-mini-128-go-starlight-2021-rec.jpg',
#   'price': '461€58'},
#  'RCDAPP0050236EXE': {'name': 'APPLE iPhone 13 Pro 128 Go Sierra Blue (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0050236exe/rw/apple-iphone-13-pro-128-go-sierra-blue-2021-re.jpg',
#   'price': '649€99'},
#  'RCDAPP0041528EXE': {'name': 'APPLE iPhone 13 256 Go Bleu - Reconditionné - Excellent état',
#   'star': 'Score global : 4 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0041528exe/rw/apple-iphone-13-256-go-bleu-reconditionne-exce.jpg',
#   'price': '536€99'},
#  'RCDAPP0037446EXE': {'name': 'APPLE iPhone 13 256 Go Midnight (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0037446exe/rw/apple-iphone-13-256-go-midnight-2021-reconditi.jpg',
#   'price': '556€98'},
#  'RCDAPP0001523EXE': {'name': 'APPLE iPhone 13 mini 128 Go Midnight (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0001523exe/rw/apple-iphone-13-mini-128-go-midnight-2021-reco.jpg',
#   'price': '470€00'},
#  'RCDAPP0032098TBE': {'name': 'APPLE iPhone 13 128 Go Midnight (2021) - Reconditionné - Très bon état',
#   'star': None,
#   'image': 'https://www.cdiscount.com/pdt2/t/b/e/1/300x300/rcdapp0032098tbe/rw/apple-iphone-13-128-go-midnight-2021-reconditi.jpg',
#   'price': '529€00'},
#  'RCDAPP0047420EXE': {'name': 'APPLE iPhone 13 Pro 128 Go Graphite (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0047420exe/rw/apple-iphone-13-pro-128-go-graphite-2021-recon.jpg',
#   'price': '649€99'},
#  'RCDAPP0004338EXE': {'name': 'APPLE iPhone 13 mini 128 Go Rouge (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0004338exe/rw/apple-iphone-13-mini-128-go-rouge-2021-recondi.jpg',
#   'price': '969,00€\nPrix de comparaison\n459€99'},
#  'RCDAPP0005604EXE': {'name': 'APPLE iPhone 13 mini 128 Go Blue (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0005604exe/rw/apple-iphone-13-mini-128-go-blue-2021-recondit.jpg',
#   'price': '499€99'},
#  'IPHONE13256BLAN2': {'name': 'APPLE iPhone 13 256GB Starlight- sans kit piéton',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/a/n/2/1/300x300/iphone13256blan2/rw/apple-iphone-13-256gb-starlight-sans-kit-pieton.jpg',
#   'price': '1029,00€\nPrix de comparaison\n829€00'},
#  'RCDAPP0038712EXE': {'name': 'APPLE iPhone 13 256 Go Starlight (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 3,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0038712exe/rw/apple-iphone-13-256-go-starlight-2021-recondit.jpg',
#   'price': '554€94'},
#  'APP0194252708637': {'name': 'iPhone 13 256Go Midnight',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/6/3/7/1/300x300/app0194252708637/rw/iphone-13-256go-midnight.jpg',
#   'price': '1029,00€\nPrix de comparaison\n829€00'},
#  'RCDAPP0033364EC': {'name': 'APPLE iPhone 13 128 Go Starlight (2021) - Reconditionné - Etat correct',
#   'star': None,
#   'image': 'https://www.cdiscount.com/pdt2/4/e/c/1/300x300/rcdapp0033364ec/rw/apple-iphone-13-128-go-starlight-2021-recondit.jpg',
#   'price': '499€00'},
#  'RCDAPP0034630TBE': {'name': 'APPLE iPhone 13 128 Go Pink (2021) - Reconditionné - Très bon état',
#   'star': 'Score global : 4 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/t/b/e/1/300x300/rcdapp0034630tbe/rw/apple-iphone-13-128-go-pink-2021-reconditionne.jpg',
#   'price': '519€00'},
#  'RCDAPP0048697EXE': {'name': 'APPLE iPhone 13 Pro 128 Go Silver (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4,5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0048697exe/rw/apple-iphone-13-pro-128-go-silver-2021-recondi.jpg',
#   'price': '629€98'},
#  'RCDAPP0033364TBE': {'name': 'APPLE iPhone 13 128 Go Starlight (2021) - Reconditionné - Très bon état',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/t/b/e/1/300x300/rcdapp0033364tbe/rw/apple-iphone-13-128-go-starlight-2021-recondit.jpg',
#   'price': '539€00'},
#  'RCDAPP0040252EXE': {'name': 'APPLE iPhone 13 256 Go Rouge (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0040252exe/rw/apple-iphone-13-256-go-rouge-2021-reconditionn.jpg',
#   'price': '535€99'},
#  'RCDAPP0049963EXE': {'name': 'APPLE iPhone 13 Pro 128 Go Gold (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 4 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0049963exe/rw/apple-iphone-13-pro-128-go-gold-2021-recondit.jpg',
#   'price': '618€69'},
#  'RCDAPP0055585EXE': {'name': 'APPLE iPhone 13 Pro 512 Go Silver (2021) - Reconditionné - Excellent état',
#   'star': None,
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0055585exe/rw/apple-iphone-13-pro-512-go-silver-2021-recondi.jpg',
#   'price': '759€99'},
#  'RCDAPP0034630EC': {'name': 'APPLE iPhone 13 128 Go Pink (2021) - Reconditionné - Etat correct',
#   'star': None,
#   'image': 'https://www.cdiscount.com/pdt2/0/e/c/1/300x300/rcdapp0034630ec/rw/apple-iphone-13-128-go-pink-2021-reconditionne.jpg',
#   'price': '528€99'},
#  'RCDAPP0031244EXE': {'name': 'APPLE iPhone 13 mini 128 Go Vert - Reconditionné - Excellent état',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0031244exe/rw/apple-iphone-13-mini-128-go-vert-reconditionne.jpg',
#   'price': '499€00'},
#  'RCDAPP0020877EXE': {'name': 'APPLE iPhone 13 Pro Max 256 Go Graphite (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0020877exe/rw/apple-iphone-13-pro-max-256-go-graphite-2021-r.jpg',
#   'price': '1050,00€\nPrix de comparaison\n832€00\nsoit 2080,00 € le kilo'},
#  'RCDAPP0047420EC': {'name': 'APPLE iPhone 13 Pro 128 Go Graphite (2021) - Reconditionné - Etat correct',
#   'star': None,
#   'image': 'https://www.cdiscount.com/pdt2/0/e/c/1/300x300/rcdapp0047420ec/rw/apple-iphone-13-pro-128-go-graphite-2021-recon.jpg',
#   'price': '637€89'},
#  'RCDAPP0037446TBE': {'name': 'APPLE iPhone 13 256 Go Midnight (2021) - Reconditionné - Très bon état',
#   'star': None,
#   'image': 'https://www.cdiscount.com/pdt2/t/b/e/1/300x300/rcdapp0037446tbe/rw/apple-iphone-13-256-go-midnight-2021-reconditi.jpg',
#   'price': '638€70'},
#  'RCDAPP0019600EC': {'name': 'APPLE iPhone 13 Pro Max 128 Go Sierra Blue (2021) - Reconditionné - Etat correct',
#   'star': 'Score global : 4 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/0/e/c/1/300x300/rcdapp0019600ec/rw/apple-iphone-13-pro-max-128-go-sierra-blue-2021.jpg',
#   'price': '699€00'},
#  'RCDAPP0016795EC': {'name': 'APPLE iPhone 13 Pro Max 128 Go Graphite (2021) - Reconditionné - Etat correct',
#   'star': None,
#   'image': 'https://www.cdiscount.com/pdt2/5/e/c/1/300x300/rcdapp0016795ec/rw/apple-iphone-13-pro-max-128-go-graphite-2021-r.jpg',
#   'price': '699€00'},
#  'RCDAPP0042795EXE': {'name': 'APPLE iPhone 13 512 Go Midnight (2021) - Reconditionné - Excellent état',
#   'star': 'Score global : 5 étoiles sur 5',
#   'image': 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0042795exe/rw/apple-iphone-13-512-go-midnight-2021-reconditi.jpg',
# RCDAPP0040252EXE  APPLE iPhone 13 256 Go Rouge (2021) - Recondit...
# RCDAPP0049963EXE  APPLE iPhone 13 Pro 128 Go Gold (2021) - Recon...
# RCDAPP0055585EXE  APPLE iPhone 13 Pro 512 Go Silver (2021) - Rec...
# RCDAPP0034630EC   APPLE iPhone 13 128 Go Pink (2021) - Reconditi...
# RCDAPP0031244EXE  APPLE iPhone 13 mini 128 Go Vert - Recondition...
# RCDAPP0020877EXE  APPLE iPhone 13 Pro Max 256 Go Graphite (2021)...
# RCDAPP0047420EC   APPLE iPhone 13 Pro 128 Go Graphite (2021) - R...
# RCDAPP0037446TBE  APPLE iPhone 13 256 Go Midnight (2021) - Recon...
# RCDAPP0019600EC   APPLE iPhone 13 Pro Max 128 Go Sierra Blue (20...
# RCDAPP0016795EC   APPLE iPhone 13 Pro Max 128 Go Graphite (2021)...
# RCDAPP0042795EXE  APPLE iPhone 13 512 Go Midnight (2021) - Recon...
# APP0194252709719        APPLE iPhone 13 256GB Blue- sans kit piéton
#
#                                               star  \
# APP0194252707289  Score global : 4,5 étoiles sur 5
# APP0194252708361  Score global : 4,5 étoiles sur 5
# APP0194252707821  Score global : 4,5 étoiles sur 5
# IP13128GREEN      Score global : 4,5 étoiles sur 5
# IPHONE13512ROUGE    Score global : 5 étoiles sur 5
# IPHONE13512ROSE     Score global : 5 étoiles sur 5
# APP0194252709177  Score global : 4,5 étoiles sur 5
# IP13256GREEN      Score global : 4,5 étoiles sur 5
# APP0194252708095    Score global : 5 étoiles sur 5
# IP13512GREEN        Score global : 5 étoiles sur 5
# RCDAPP0032098EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0034630EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0033364EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0036170EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0029011EXE    Score global : 4 étoiles sur 5
# RCDAPP0003062EXE    Score global : 5 étoiles sur 5
# RCDAPP0035906EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0039989EXE    Score global : 4 étoiles sur 5
# RCDAPP0002790EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0050236EXE    Score global : 4 étoiles sur 5
# RCDAPP0041528EXE    Score global : 4 étoiles sur 5
# RCDAPP0037446EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0001523EXE    Score global : 5 étoiles sur 5
# RCDAPP0032098TBE                              None
# RCDAPP0047420EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0004338EXE    Score global : 5 étoiles sur 5
# RCDAPP0005604EXE  Score global : 4,5 étoiles sur 5
# IPHONE13256BLAN2  Score global : 4,5 étoiles sur 5
# RCDAPP0038712EXE  Score global : 3,5 étoiles sur 5
# APP0194252708637  Score global : 4,5 étoiles sur 5
# RCDAPP0033364EC                               None
# RCDAPP0034630TBE    Score global : 4 étoiles sur 5
# RCDAPP0048697EXE  Score global : 4,5 étoiles sur 5
# RCDAPP0033364TBE    Score global : 5 étoiles sur 5
# RCDAPP0034630TBE                                             519€00
# RCDAPP0048697EXE                                             629€98
# RCDAPP0033364TBE                                             539€00
# RCDAPP0040252EXE                                             535€99
# RCDAPP0049963EXE                                             618€69
# RCDAPP0055585EXE                                             759€99
# RCDAPP0034630EC                                              528€99
# RCDAPP0031244EXE                                             499€00
# RCDAPP0020877EXE  1050,00€\nPrix de comparaison\n832€00\nsoit 20...
# RCDAPP0047420EC                                              637€89
# RCDAPP0037446TBE                                             638€70
# RCDAPP0019600EC                                              699€00
# RCDAPP0016795EC                                              699€00
# RCDAPP0042795EXE                                             654€98
# APP0194252709719              1029,00€\nPrix de comparaison\n829€00

# %%
database = DataBase('data/data_cdiscount')
database.table
# Out:
# /var/folders/xg/zbz96gcd1l318nfzl96_m9dm0000gn/T/ipykernel_16814/4235633602.py:11: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   self.table = self.engine.table_names()
# ['Iphon 13', 'Samsung_TV_Oled', 'TV_4K']

# %%
database.select_table('Iphon 13')
# Out:
# [('APP0194252707289', 'iPhone 13 128Go Midnight', 'Score global : 4,5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/2/8/9/1/300x300/app0194252707289/rw/iphone-13-128go-midnight.jpg', '909,00€\nPrix de comparaison\n699€00'),
#  ('APP0194252708361', 'iPhone 13 128Go Blue', 'Score global : 4,5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/3/6/1/1/300x300/app0194252708361/rw/iphone-13-128go-blue.jpg', '909,00€\nPrix de comparaison\n699€00'),
#  ('APP0194252707821', 'iPhone 13 128Go Pink', 'Score global : 4,5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/8/2/1/1/300x300/app0194252707821/rw/iphone-13-128go-pink.jpg', '909,00€\nPrix de comparaison\n699€00'),
#  ('IP13128GREEN', 'iPhone 13 128Go Vert', 'Score global : 4,5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/e/e/n/1/300x300/ip13128green/rw/iphone-13-128go-vert.jpg', '909,00€\nPrix de comparaison\n699€00'),
#  ('IPHONE13512ROUGE', 'APPLE iPhone 13 512Go (PRODUCT) RED', 'Score global : 5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/u/g/e/1/300x300/iphone13512rouge/rw/apple-iphone-13-512go-product-red.jpg', '1259,00€\nPrix de comparaison\n1079€00'),
#  ('IPHONE13512ROSE', 'APPLE iPhone 13 512Go Pink', 'Score global : 5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/o/s/e/1/300x300/iphone13512rose/rw/apple-iphone-13-512go-pink.jpg', '1259,00€\nPrix de comparaison\n1079€00'),
#  ('APP0194252709177', 'iPhone 13 256Go Pink', 'Score global : 4,5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/1/7/7/1/300x300/app0194252709177/rw/iphone-13-256go-pink.jpg', '1029,00€\nPrix de comparaison\n829€00'),
#  ('RCDAPP0034630EC', 'APPLE iPhone 13 128 Go Pink (2021) - Reconditionné - Etat correct', None, 'https://www.cdiscount.com/pdt2/0/e/c/1/300x300/rcdapp0034630ec/rw/apple-iphone-13-128-go-pink-2021-reconditionne.jpg', '528€99'),
#  ('RCDAPP0031244EXE', 'APPLE iPhone 13 mini 128 Go Vert - Reconditionné - Excellent état', 'Score global : 5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0031244exe/rw/apple-iphone-13-mini-128-go-vert-reconditionne.jpg', '499€00'),
#  ('RCDAPP0020877EXE', 'APPLE iPhone 13 Pro Max 256 Go Graphite (2021) - Reconditionné - Excellent état', 'Score global : 5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0020877exe/rw/apple-iphone-13-pro-max-256-go-graphite-2021-r.jpg', '1050,00€\nPrix de comparaison\n832€00\nsoit 2080,00 € le kilo'),
#  ('RCDAPP0047420EC', 'APPLE iPhone 13 Pro 128 Go Graphite (2021) - Reconditionné - Etat correct', None, 'https://www.cdiscount.com/pdt2/0/e/c/1/300x300/rcdapp0047420ec/rw/apple-iphone-13-pro-128-go-graphite-2021-recon.jpg', '637€89'),
#  ('RCDAPP0037446TBE', 'APPLE iPhone 13 256 Go Midnight (2021) - Reconditionné - Très bon état', None, 'https://www.cdiscount.com/pdt2/t/b/e/1/300x300/rcdapp0037446tbe/rw/apple-iphone-13-256-go-midnight-2021-reconditi.jpg', '638€70'),
#  ('RCDAPP0019600EC', 'APPLE iPhone 13 Pro Max 128 Go Sierra Blue (2021) - Reconditionné - Etat correct', 'Score global : 4 étoiles sur 5', 'https://www.cdiscount.com/pdt2/0/e/c/1/300x300/rcdapp0019600ec/rw/apple-iphone-13-pro-max-128-go-sierra-blue-2021.jpg', '699€00'),
#  ('RCDAPP0016795EC', 'APPLE iPhone 13 Pro Max 128 Go Graphite (2021) - Reconditionné - Etat correct', None, 'https://www.cdiscount.com/pdt2/5/e/c/1/300x300/rcdapp0016795ec/rw/apple-iphone-13-pro-max-128-go-graphite-2021-r.jpg', '699€00'),
#  ('RCDAPP0042795EXE', 'APPLE iPhone 13 512 Go Midnight (2021) - Reconditionné - Excellent état', 'Score global : 5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/e/x/e/1/300x300/rcdapp0042795exe/rw/apple-iphone-13-512-go-midnight-2021-reconditi.jpg', '654€98'),
#  ('APP0194252709719', 'APPLE iPhone 13 256GB Blue- sans kit piéton', 'Score global : 4,5 étoiles sur 5', 'https://www.cdiscount.com/pdt2/7/1/9/1/300x300/app0194252709719/rw/apple-iphone-13-256gb-blue-sans-kit-pieton.jpg', '1029,00€\nPrix de comparaison\n829€00')]

# %%
options = Options()
options.add_argument("--headless")

driver = webdriver.Chrome('./chromedriver', options=options)

driver.get('https://www.cdiscount.com/')
time.sleep(2)

# Accept cookies
#driver.find_element(By.ID, "footer_tc_privacy_button_2").click()

# Search for a product
driver.find_element(By.ID, 'search').send_keys('IPHONE 13' + Keys.ENTER)
